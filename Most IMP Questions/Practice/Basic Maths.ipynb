# %% [markdown]
# # Basic Maths

# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Count-Digits" data-toc-modified-id="Count-Digits-1">Count Digits</a></span></li><li><span><a href="#Check-Palindrome" data-toc-modified-id="Check-Palindrome-2">Check Palindrome</a></span></li><li><span><a href="#Armstrong-Number" data-toc-modified-id="Armstrong-Number-3">Armstrong Number</a></span></li><li><span><a href="#Reverse-Number" data-toc-modified-id="Reverse-Number-4">Reverse Number</a></span><ul class="toc-item"><li><span><a href="#Leetcode" data-toc-modified-id="Leetcode-4.1">Leetcode</a></span></li></ul></li><li><span><a href="#Sum-of-Divisors" data-toc-modified-id="Sum-of-Divisors-5">Sum of Divisors</a></span></li><li><span><a href="#Check-Prime" data-toc-modified-id="Check-Prime-6">Check Prime</a></span></li><li><span><a href="#Find-GCD-/-HCF" data-toc-modified-id="Find-GCD-/-HCF-7">Find GCD / HCF</a></span></li></ul></div>

# %% [markdown]
# ## Count Digits

# %% [markdown]
# ![image-3.png](attachment:image-3.png)
#
# ![image-4.png](attachment:image-4.png)
# > we ignore `0` as it raises `Artihmetic error zero division`
#
# ![image-2.png](attachment:image-2.png)

# %%
def countDigits(n: int) -> int:
    count = 0
    for i in str(n):
        if i == '0':
            continue
        elif n % int(i) == 0:
            count += 1
    return count

# %% [markdown]
# ## Check Palindrome
#
# ![image-2.png](attachment:image-2.png)
# ![image-4.png](attachment:image-4.png)

# %%
## write your code !!
def paliCheck(n):
    n1 = str(n)
    i = 0 
    j = len(n1) - 1
    while i <= j:
        if n1[i] != n1[j]:
            return "false"
        else:
            i += 1
            j -= 1
    return "true"
k = paliCheck(1221)
print(k)
# Out:
# true

# %%
n=int(input())  
# taking n as a input 
## write your code !!
def paliCheck(n):
    dp = n
    revNum = 0
    while n > 0:
        lastNum = n % 10
        revNum = (revNum * 10) + lastNum
        n = n // 10
    if dp == revNum:
        return "true"
    else:
        return "false"


k = paliCheck(n)
print(k)
# Out:
# 5231
# false

# %% [markdown]
# ## Armstrong Number
# ![image.png](attachment:image.png)
# ![image-4.png](attachment:image-4.png)

# %%
from os import *
from sys import *
from collections import *
from math import *
# n = input()
def ArmstrongNumber(n):
    sumV = 0
    length = len(n)
    for i in n:
        sumV += (int(i) ** length)

    return 'true' if sumV == int(n) else 'false'
k = ArmstrongNumber('1634')
print(k)
# Out:
# true

# %% [markdown]
# ## Reverse Number

# %% [markdown]
# ### Leetcode

# %% [markdown]
# ![image-2.png](attachment:image-2.png)
#
# * `% 10`: return the last value
# * `// 10`: floor the value reduce a unit number

# %%
class Solution:
    def reverse(self, x: int) -> int:
        revnum = 0
        neg = False
        if x < 0: 
            x = abs(x)
            neg = True
        while x > 0:
            lastnum = x % 10
            x = x // 10
            revnum = (revnum * 10) + lastnum
        if revnum <= 2**31 - 1 and not neg:
            return revnum
        elif revnum <= 2**31 - 1 and neg:
            return -revnum
        else:
            return 0

# %% [markdown]
# ## Sum of Divisors

# %% [markdown]
# ![image-2.png](attachment:image-2.png)
# ![image-3.png](attachment:image-3.png)
# ![image.png](attachment:image.png)

# %%
def sumOfAllDivisors(n: int) -> int:
    def sumDivisor(n):
        val = 0
        for i in range(1,n+1):
            if n % i == 0:
                val += i
        return val
    res = 0
    for i in range(1, n +1):
        res += sumDivisor(i)
    return res

# %% [markdown]
# ## Check Prime
#
# ![image.png](attachment:image.png)

# %%
from math import *
from collections import *
from sys import *
from os import *

## Read input as specified in the question.
## Print output as specified in the question.
n = int(input())
def checkPrime(n):
    count = 0
    for i in range(1,int(sqrt(n)) + 1):
        if n % i == 0:
            count += 1
            if ((n // i) != i):
                count += 1
    if count == 2:
        return 'YES'
    else:
        return 'NO'
k = checkPrime(n)
print(k)
# Out:
# 5
# YES

# %% [markdown]
# ## Find GCD / HCF
#
#
# ![image-2.png](attachment:image-2.png)

# %%
def calcGDC(n:int, m: int) -> int:
    # Write your code here
    k = min(n, m)
    for i in range(1, k + 1):
        if (n % i) == 0 and (m % i) == 0:
            val = i
    return val

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def calcGDC(n:int, m: int) -> int:
    # Write your code here
    val = 1
    k = min(n, m)
    for i in range(k, 0, -1):
        if (n % i) == 0 and (m % i) == 0:
            val = i
            break
    return val

# %%
def calcGCD(n, m):
    while (n > 0 and m > 0):
        if n > m: n = n % m
        else: m = m % n
    if n == 0: return m
    return n
