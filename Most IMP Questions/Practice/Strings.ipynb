# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Reverse-Words-in-a-String" data-toc-modified-id="Reverse-Words-in-a-String-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Reverse Words in a String</a></span></li><li><span><a href="#Largest-Odd-Number-in-a-String" data-toc-modified-id="Largest-Odd-Number-in-a-String-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Largest Odd Number in a String</a></span></li></ul></div>

# %% [markdown]
# ## Reverse Words in a String
#
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %%
def reverseString(s: str) -> str:
    # split the string (by default it uses spaces)
    str_list = s.split()
    res = []
    # for loop from end to start
    for i in range(len(str_list) - 1, -1, -1):
        res.append(str_list[i])
        # join the arr with spaces
    return " ".join(res)

# %%
def reverseString(s: str) -> str:
    # similar approach than above but we have used while loop
    # for changing to swapping the position
    str_list = s.split()
    start = 0
    end = len(str_list) - 1
    while start <= end:
        str_list[start], str_list[end] = str_list[end], str_list[start]
        start += 1
        end -= 1
    return " ".join(str_list)

# %% [markdown]
# ## Largest Odd Number in a String
#
# ![image.png](attachment:image.png)

# %%
# go from end and check if the last num is odd if yes return the num
class Solution:
    def largestOddNumber(self, num: str) -> str:
        i = len(num) - 1
        while i >= 0:
            if int(num[i]) % 2 == 1:
                return num[:i+1]
            i -= 1
        return ''
