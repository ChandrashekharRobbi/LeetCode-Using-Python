# %% [markdown]
# # Basic Maths

# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Count-Digits" data-toc-modified-id="Count-Digits-1">Count Digits</a></span></li><li><span><a href="#Check-Palindrome" data-toc-modified-id="Check-Palindrome-2">Check Palindrome</a></span></li><li><span><a href="#Armstrong-Number" data-toc-modified-id="Armstrong-Number-3">Armstrong Number</a></span></li><li><span><a href="#Reverse-Number" data-toc-modified-id="Reverse-Number-4">Reverse Number</a></span><ul class="toc-item"><li><span><a href="#Leetcode" data-toc-modified-id="Leetcode-4.1">Leetcode</a></span></li></ul></li></ul></div>

# %% [markdown]
# ## Count Digits

# %% [markdown]
# [![](https://mermaid.ink/img/pako:eNpVks1u2zAQhF9lsUARG1AMSZElWYcWiZ3EPiSHppcWuhDS2iYqkSq1LJIIfvdQlNOkPPHnm-UMlwNWuiYs8GBEd4Qfm1KBG9ez2RMLw_M5XF5-hZthpyRL0chXgkpbxcAawtME33hmPeyYjGACPhptD0eo5UFyD3oP6kyuPbkZStz1DqMJgYvw4luJZ2bjGPhJvUdvHbrWiqWyBLP-t-ycTPaTbv6_5lF7yd0oEU1lm9GLgi8gFc_kB3w3wrd_rGh6CL3k3sWrDLXkcvl0Z_Len26HB_2XxsCjY0XPPF1_hrZT-k-1HzUDfa6__UgP103z_jCd0RX1PdUe2g3fia1R_xxggC2ZVsjatWcYS5ToHLRUYuGmNe2FbbjEUp0cKizrpxdVYcHGUoC2q13-jRSusS0We-fG7XZC_dK6fYfcEosBn7GI8nSxyq6yJA6jOA2XYRLgCxbZIs7yZBWFWRyvojRJTgG--gLhYpWneZ5EUXYVxmm8XAZItWRtHqYP5f_V6Q0GxbXJ?type=png)](https://mermaid.live/edit#pako:eNpVks1u2zAQhF9lsUARG1AMSZElWYcWiZ3EPiSHppcWuhDS2iYqkSq1LJIIfvdQlNOkPPHnm-UMlwNWuiYs8GBEd4Qfm1KBG9ez2RMLw_M5XF5-hZthpyRL0chXgkpbxcAawtME33hmPeyYjGACPhptD0eo5UFyD3oP6kyuPbkZStz1DqMJgYvw4luJZ2bjGPhJvUdvHbrWiqWyBLP-t-ycTPaTbv6_5lF7yd0oEU1lm9GLgi8gFc_kB3w3wrd_rGh6CL3k3sWrDLXkcvl0Z_Len26HB_2XxsCjY0XPPF1_hrZT-k-1HzUDfa6__UgP103z_jCd0RX1PdUe2g3fia1R_xxggC2ZVsjatWcYS5ToHLRUYuGmNe2FbbjEUp0cKizrpxdVYcHGUoC2q13-jRSusS0We-fG7XZC_dK6fYfcEosBn7GI8nSxyq6yJA6jOA2XYRLgCxbZIs7yZBWFWRyvojRJTgG--gLhYpWneZ5EUXYVxmm8XAZItWRtHqYP5f_V6Q0GxbXJ)

# %%
def countDigits(n: int) -> int:
    count = 0
    for i in str(n):
        if i == '0':
            continue
        elif n % int(i) == 0:
            count += 1
    return count

# %% [markdown]
# ## Check Palindrome
#
# ![image-2.png](attachment:image-2.png)
# ![image-3.png](attachment:image-3.png)

# %%
## write your code !!
def paliCheck(n):
    n1 = str(n)
    i = 0 
    j = len(n1) - 1
    while i <= j:
        if n1[i] != n1[j]:
            return "false"
        else:
            i += 1
            j -= 1
    return "true"
k = paliCheck(1221)
print(k)
# Out:
# true

# %% [markdown]
# ## Armstrong Number
# ![image.png](attachment:image.png)
#
#
# ![image-3.png](attachment:image-3.png)

# %%
from os import *
from sys import *
from collections import *
from math import *
# n = input()
def ArmstrongNumber(n):
    sumV = 0
    length = len(n)
    for i in n:
        sumV += (int(i) ** length)

    return 'true' if sumV == int(n) else 'false'
k = ArmstrongNumber('1634')
print(k)
# Out:
# true

# %% [markdown]
# ## Reverse Number

# %% [markdown]
# ### Leetcode

# %% [markdown]
# ![image-2.png](attachment:image-2.png)
#
# * `% 10`: return the last value
# * `// 10`: floor the value reduce a unit number

# %%
class Solution:
    def reverse(self, x: int) -> int:
        revnum = 0
        neg = False
        if x < 0: 
            x = abs(x)
            neg = True
        while x > 0:
            lastnum = x % 10
            x = x // 10
            revnum = (revnum * 10) + lastnum
        if revnum <= 2**31 - 1 and not neg:
            return revnum
        elif revnum <= 2**31 - 1 and neg:
            return -revnum
        else:
            return 0
